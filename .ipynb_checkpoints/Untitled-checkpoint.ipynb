# %%
plt.figure()
plt.plot(model.evals_result()['validation_0']['logloss'], label='训练')
plt.title('学习曲线-张驰')
plt.xlabel('轮数')
plt.ylabel('损失')
plt.legend()
plt.show()

# %%
# 绘制ROC曲线
plt.figure()
plt.plot(fpr_train, tpr_train, label='训练ROC曲线 (area = %0.2f)' % roc_auc_train)
plt.plot(fpr_val, tpr_val, label='验证ROC曲线 (area = %0.2f)' % roc_auc_val)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('假正例率')
plt.ylabel('真正例率')
plt.title('ROC曲线-张驰')
plt.legend(loc="lower right")
plt.show()

# %%
# 绘制学习曲线
plt.figure()
plt.plot(relu_train_losses, label='训练损失')
plt.plot(relu_val_losses, label='验证损失')
plt.xlabel('轮数')
plt.ylabel('损失')
plt.title('学习曲线-张驰')
plt.legend()
plt.show()

# %%
# 计算AUC
fpr, tpr, _ = roc_curve(relu_y_test_pred, relu_y_test_prob)
roc_auc = auc(fpr, tpr)

# 绘制ROC曲线
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC曲线 (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('假正例率')
plt.ylabel('真正例率')
plt.title('ROC曲线-张驰')
plt.legend(loc="lower right")
plt.show()

# %%
# 计算AUC
fpr, tpr, _ = roc_curve(deep_relu_y_test_pred, deep_relu_y_test_prob)
roc_auc = auc(fpr, tpr)

# 绘制ROC曲线
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC曲线 (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('假正例率')
plt.ylabel('真正例率')
plt.title('ROC曲线-张驰')
plt.legend(loc="lower right")
plt.show()

# %%
# 绘制学习曲线
plt.figure()
plt.plot(relu_train_losses, label='训练损失')
plt.plot(relu_val_losses, label='验证损失')
plt.xlabel('轮数')
plt.ylabel('损失')
plt.title('学习曲线-张驰')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# 计算AUC
fpr, tpr, _ = roc_curve(relu_y_test_pred.numpy(), relu_y_test_prob.numpy())
roc_auc = auc(fpr, tpr)

# 绘制ROC曲线
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC曲线 (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('假正例率')
plt.ylabel('真正例率')
plt.title('ROC曲线-张驰')
plt.legend(loc="lower right")
plt.show()

# %%
# 绘制学习曲线
plt.figure()
plt.plot(silu_train_losses, label='学习损失')
plt.plot(silu_val_losses, label='验证损失')
plt.xlabel('轮数')
plt.ylabel('损失')
plt.title('学习曲线-张驰')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# 计算AUC
fpr, tpr, _ = roc_curve(silu_y_test_pred.numpy(), silu_y_test_prob.numpy())
roc_auc = auc(fpr, tpr)

# 绘制ROC曲线
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC曲线 (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('假正例率')
plt.ylabel('真正例率')
plt.title('ROC曲线-张驰')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.metrics import roc_curve, auc

# 绘制学习曲线
train_sizes, train_scores, test_scores = learning_curve(model, X_train, y_train, cv=10)
train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)

plt.figure()
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="训练得分")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="交叉验证得分")
plt.xlabel("训练样本数")
plt.ylabel("得分")
plt.legend(loc="best")
plt.title("学习曲线-张驰")
plt.show()

# %%
# 绘制ROC曲线
y_pred_proba = model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', label='ROC曲线 (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('假阳性率')
plt.ylabel('真阳性率')
plt.title('ROC曲线-张驰')
plt.legend(loc="lower right")
plt.show()
